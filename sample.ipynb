# %% [markdown]
# <a href="https://colab.research.google.com/github/Raajarapu/COLAB_practice/blob/main/sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HI")
# Out:
# HI
